# %%
from load_data import load_data

df = load_data()
# Out:
# Train samples = 159571
# Test cleaned samples = 63978

# %%
from utils import \
plot_label_distribution, \
plot_labels_per_comment, \
plot_comment_length, \
plot_label_correlation, \
plot_length_vs_toxicity

# %%
plot_label_distribution(df)

# %%
plot_labels_per_comment(df)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 248327    3
# 248328    0
# 248329    3
# 248330    3
# 248331    0
# Length: 248332, dtype: int64

# %%
plot_comment_length(df)

# %%
plot_label_correlation(df)

# %%
plot_length_vs_toxicity(df)
